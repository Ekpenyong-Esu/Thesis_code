# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Read data from the first file
file_path1 = r'C:\Users\mahon\Desktop\Videolatency\Node2\pythonProject\processing_latency.txt'
with open(file_path1, 'r') as file:
    node2_processing_latency = [float(line.strip()) for line in file.readlines()]

# Read data from the second file
file_path2 = r'C:\Users\mahon\Desktop\Videolatency\nonRealtime\node2\pythonProject\processing_latency.txt'
with open(file_path2, 'r') as file:
    node2_non_realtime_latency = [float(line.strip()) for line in file.readlines()]

# Create a DataFrame from the data
data = {
    'Node': ['RT_PATCH'] * len(node2_processing_latency) + ['Non RT_PATCH'] * len(node2_non_realtime_latency),
    'Latency (ms)': node2_processing_latency + node2_non_realtime_latency
}

df = pd.DataFrame(data)

# Set style
sns.set(style="whitegrid")

# Plotting box plot
plt.figure(figsize=(12, 6))
sns.boxplot(x='Node', y='Latency (ms)', data=df)
plt.title('Node2 showing Processing Latency of real time RT_PATCH and Non Real Time Latency')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Read data from the first file
file_path1 = r'C:\Users\mahon\Desktop\Videolatency\Node2\pythonProject\communication_latency.txt'
with open(file_path1, 'r') as file:
    node2_processing_latency = [float(line.strip()) for line in file.readlines()]

# Read data from the second file
file_path2 = r'C:\Users\mahon\Desktop\Videolatency\nonRealtime\node2\pythonProject\communication_latency.txt'
with open(file_path2, 'r') as file:
    node2_non_realtime_latency = [float(line.strip()) for line in file.readlines()]

# Create a DataFrame from the data
data = {
    'Node': ['RT_PATCH'] * len(node2_processing_latency) + ['Non RT_PATCH'] * len(node2_non_realtime_latency),
    'Latency (ms)': node2_processing_latency + node2_non_realtime_latency
}

df = pd.DataFrame(data)

# Plotting box plot
plt.figure(figsize=(10, 6))

sns.boxplot(x='Node', y='Latency (ms)', data=df, palette='Set3')
plt.title('Node2 showing comunication Latency over TSN with real time RT_PATCH and Non Real Time Latency')
plt.show()

# %%
# NODE 2 PROCESSING LATENCY

import pandas as pd
processing_latency1 = r'C:\Users\mahon\Desktop\Videolatency\Node2\pythonProject\processing_latency.txt'

# Read the data from file
data1 = pd.read_csv(processing_latency1, header=None)

# Filter data points based on index condition
filtered_data1 = data1[data1.index <= 1000]


filtered_data1.head

print(filtered_data1.max())
print(filtered_data1.min())
print(filtered_data1.mean())
# Out:
# 0    13.07
# dtype: float64
# 0    8.72
# dtype: float64
# 0    10.911988
# dtype: float64

# %%
import pandas as pd
processing_latency2 = r'C:\Users\mahon\Desktop\Videolatency\nonRealtime\node2\pythonProject\processing_latency.txt'

# Read the data from file
data2 = pd.read_csv(processing_latency2, header=None)

# Filter data points based on index condition
filtered_data2 = data2[data2.index <= 1000]


filtered_data2.head

print(filtered_data2.max())
print(filtered_data2.min())
print(filtered_data2.mean())
# Out:
# 0    19.83
# dtype: float64
# 0    12.67
# dtype: float64
# 0    16.234146
# dtype: float64

# %%
# NODE 2 COMMUNICATION LATENCY

import pandas as pd
communication_latency1 = r'C:\Users\mahon\Desktop\Videolatency\Node2\pythonProject\communication_latency.txt'
# Read the data from file
data1 = pd.read_csv(communication_latency1, header=None)

# Filter data points based on index condition
filtered_data1 = data1[data1.index <= 1000]


filtered_data1.head

print(filtered_data1.max())
print(filtered_data1.min())
print(filtered_data1.mean())
# Out:
# 0    16.11
# dtype: float64
# 0    10.06
# dtype: float64
# 0    13.085255
# dtype: float64

# %%
# NODE 2 communication LATENCY

import pandas as pd
communication_latency2 = r'C:\Users\mahon\Desktop\Videolatency\nonRealtime\node2\pythonProject\communication_latency.txt'
# Read the data from file
data2 = pd.read_csv(communication_latency2, header=None)

# Filter data points based on index condition
filtered_data2 = data2[data2.index <= 1000]


filtered_data2.head

print(filtered_data2.max())
print(filtered_data2.min())
print(filtered_data2.mean())
# Out:
# 0    28.1
# dtype: float64
# 0    21.05
# dtype: float64
# 0    24.658761
# dtype: float64

# %%
file_path1 = r'C:\Users\mahon\Desktop\Videolatency\Node2\pythonProject\processing_latency.txt'
file_path2 = r'C:\Users\mahon\Desktop\Videolatency\Node2\pythonProject\communication_latency.txt'


# Read the data from file
data1 = pd.read_csv(file_path1, header=None)

data2 = pd.read_csv(file_path2, header=None)

# Filter data points based on index condition
filtered_data1 = data1[data1.index <= 1000]

filtered_data2 = data2[data2.index <= 1000]


sum_arr = filtered_data1 + filtered_data2

filtered_data2.head


print(sum_arr.max())
print(sum_arr.min())
print(sum_arr.mean())
# Out:
# 0    29.06
# dtype: float64
# 0    18.84
# dtype: float64
# 0    23.997243
# dtype: float64

# %%
file_path1 = r'C:\Users\mahon\Desktop\Videolatency\nonRealtime\node2\pythonProject\processing_latency.txt'
file_path2 = r'C:\Users\mahon\Desktop\Videolatency\nonRealtime\node2\pythonProject\communication_latency.txt'


# Read the data from file
data1 = pd.read_csv(file_path1, header=None)

data2 = pd.read_csv(file_path2, header=None)

# Filter data points based on index condition
filtered_data1 = data1[data1.index <= 1000]

filtered_data2 = data2[data2.index <= 1000]


sum_arr = filtered_data1 + filtered_data2

filtered_data2.head


print(sum_arr.max())
print(sum_arr.min())
print(sum_arr.mean())
# Out:
# 0    47.65
# dtype: float64
# 0    33.93
# dtype: float64
# 0    40.892907
# dtype: float64
