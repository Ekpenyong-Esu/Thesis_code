# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Read data from the first file
file_path1 = r'C:\Users\mahon\Desktop\Videolatency\Node3\pythonProject1\processing_latency.txt'
with open(file_path1, 'r') as file:
    node2_processing_latency = [float(line.strip()) for line in file.readlines()]

# Read data from the second file
file_path2 = r'C:\Users\mahon\Desktop\Videolatency\nonRealtime\node3\pythonProject1\processing_latency.txt'
with open(file_path2, 'r') as file:
    node2_non_realtime_latency = [float(line.strip()) for line in file.readlines()]

# Create a DataFrame from the data
data = {
    'Node': ['RT_PATCH'] * len(node2_processing_latency) + ['Non RT_PATCH'] * len(node2_non_realtime_latency),
    'Latency (ms)': node2_processing_latency + node2_non_realtime_latency
}

df = pd.DataFrame(data)

# Set style
sns.set(style="whitegrid")

# Plotting box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Node', y='Latency (ms)', data=df)
plt.title('Node3 showing Processing Latency of real time RT_PATCH and Non Real Time Latency')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Read data from the first file
file_path1 = r'C:\Users\mahon\Desktop\Videolatency\Node3\pythonProject1\communication_latency.txt'
with open(file_path1, 'r') as file:
    node2_processing_latency = [float(line.strip()) for line in file.readlines()]

# Read data from the second file
file_path2 = r'C:\Users\mahon\Desktop\Videolatency\nonRealtime\node3\pythonProject1\communication_latency.txt'
with open(file_path2, 'r') as file:
    node2_non_realtime_latency = [float(line.strip()) for line in file.readlines()]

# Create a DataFrame from the data
data = {
    'Node': ['RT_PATCH'] * len(node2_processing_latency) + ['Non RT_PATCH'] * len(node2_non_realtime_latency),
    'Latency (ms)': node2_processing_latency + node2_non_realtime_latency
}

df = pd.DataFrame(data)

# Set style
sns.set(style="whitegrid")

# Plotting box plot
plt.figure(figsize=(10, 6))

sns.boxplot(x='Node', y='Latency (ms)', data=df, palette='Set3')
plt.title('Node3 showing comunication Latency over TSN with real time RT_PATCH and Non Real Time Latency')
plt.show()

# %%
# NODE 3 processing LATENCY



import pandas as pd
processing_latency1 = r'C:\Users\mahon\Desktop\Videolatency\Node3\pythonProject1\processing_latency.txt'

# Read the data from file
data1 = pd.read_csv(processing_latency1, header=None)

# Filter data points based on index condition
filtered_data1 = data1[data1.index <= 1000]


filtered_data1.head

print(filtered_data1.max())
print(filtered_data1.min())
print(filtered_data1.mean())
# Out:
# 0    11.97
# dtype: float64
# 0    6.73
# dtype: float64
# 0    9.334505
# dtype: float64

# %%
import pandas as pd
processing_latency2 = r'C:\Users\mahon\Desktop\Videolatency\nonRealtime\node3\pythonProject1\processing_latency.txt'

# Read the data from file
data2 = pd.read_csv(processing_latency2, header=None)

# Filter data points based on index condition
filtered_data2 = data2[data2.index <= 1000]


filtered_data2.head

print(filtered_data2.max())
print(filtered_data2.min())
print(filtered_data2.mean())
# Out:
# 0    21.56
# dtype: float64
# 0    16.51
# dtype: float64
# 0    19.026364
# dtype: float64

# %%
# NODE 3 communication LATENCY

import pandas as pd
communication_latency1 = r'C:\Users\mahon\Desktop\Videolatency\Node3\pythonProject1\communication_latency.txt'
# Read the data from file
data1 = pd.read_csv(communication_latency1, header=None)

# Filter data points based on index condition
filtered_data1 = data1[data1.index <= 1000]


filtered_data1.head

print(filtered_data1.max())
print(filtered_data1.min())
print(filtered_data1.mean())
# Out:
# 0    40.95
# dtype: float64
# 0    31.99
# dtype: float64
# 0    36.58973
# dtype: float64

# %%
import pandas as pd
communication_latency2 = r'C:\Users\mahon\Desktop\Videolatency\nonRealtime\node3\pythonProject1\communication_latency.txt'
# Read the data from file
data2 = pd.read_csv(communication_latency2, header=None)

# Filter data points based on index condition
filtered_data2 = data2[data2.index <= 1000]


filtered_data2.head

print(filtered_data2.max())
print(filtered_data2.min())
print(filtered_data2.mean())
# Out:
# 0    82.82
# dtype: float64
# 0    56.83
# dtype: float64
# 0    70.029211
# dtype: float64

# %%
file_path1 = r'C:\Users\mahon\Desktop\Videolatency\Node3\pythonProject1\processing_latency.txt'
file_path2 = r'C:\Users\mahon\Desktop\Videolatency\Node3\pythonProject1\communication_latency.txt'


# Read the data from file
data1 = pd.read_csv(file_path1, header=None)

data2 = pd.read_csv(file_path2, header=None)

# Filter data points based on index condition
filtered_data1 = data1[data1.index <= 1000]

filtered_data2 = data2[data2.index <= 1000]


sum_arr = filtered_data1 + filtered_data2

filtered_data2.head


print(sum_arr.max())
print(sum_arr.min())
print(sum_arr.mean())
# Out:
# 0    52.63
# dtype: float64
# 0    39.16
# dtype: float64
# 0    45.924236
# dtype: float64

# %%
file_path1 = r'C:\Users\mahon\Desktop\Videolatency\nonRealtime\node3\pythonProject1\processing_latency.txt'
file_path2 = r'C:\Users\mahon\Desktop\Videolatency\nonRealtime\node3\pythonProject1\communication_latency.txt'


# Read the data from file
data1 = pd.read_csv(file_path1, header=None)

data2 = pd.read_csv(file_path2, header=None)

# Filter data points based on index condition
filtered_data1 = data1[data1.index <= 1000]

filtered_data2 = data2[data2.index <= 1000]


sum_arr = filtered_data1 + filtered_data2

filtered_data2.head


print(sum_arr.max())
print(sum_arr.min())
print(sum_arr.mean())
# Out:
# 0    104.03
# dtype: float64
# 0    73.91
# dtype: float64
# 0    89.055574
# dtype: float64
